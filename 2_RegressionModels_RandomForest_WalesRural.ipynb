# %% [markdown]
# # 2 Machine Learning Models

# %% [markdown]
# ## 2.X Random Forest Regression

# %% [markdown]
# This notebook runs the Random Forest regression model (an ensemble method based on an averaged (forest) randomised decision tree model) from the SciKit Learn python library (https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor).

# %% [markdown]
# The problem posed is to predict electricity consumption at a local (LSOA) level, the data is therefore continuous and numerical and is labelled. This lends to supervised machine learning (ML) and regression models.
#
# It is hypothesised that there will be a correlation between mean house price sales (as an indicator of general prosperity and condition of a property) and electricity consumption. This data has previously been cleaned, is read in and split into training and test data. Results are printed in line and exported to csv for comparison against other regression models.

# %% [markdown]
# The feature variables include: 'Year', 'Mean price paid', and OS coordinate location data for the population weighted centroid of the LSOAs.

# %% [markdown]
# Initially the models were tested with 'Year' and 'Mean price paid', followed by a second model run with all the above feature variables included.

# %% [markdown]
# Random Forest has several hyperparameters that are used to refine the model. The hyperparameters varied within the below model runs are:
# 1. Number of estimators - which is the number of trees in the forest, the default is set to 100 and increasing substantially has a knock on to run time.
# 2. Criterion - whether the model averages based on MSE or MAE. MSE is substantially faster, with MAE throwing runtime and memory issues. Whilst MAE could be a better predictor this has therefore not been explored.
# 3. Maximum depth of the tree - aka number of branches - the default is none with the model running until pure.
# 4. Random State - randomness of samples taken and also randomness of features considered at each node / branch. It is not known what effect this will on the model.
#
# All other hyperparameters are not specified and set to the default values.

# %% [markdown]
# ## 2.3.1 Import Model Libraries

# %% [markdown]
# Data handling and scientific libraries used include:
#
# numpy - (scientific numerical package for Python that enables working with arrays) pandas - (data analysis library) matplotlib - (enables plotting and visualisation in Python) openpyxl / load_workbook (opens Excel xlsx files)

# %%
#Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from openpyxl import load_workbook

# %% [markdown]
# Imports the Random Forest Regressor model from the SciKit Learn ensemble library.

# %%
#Import ML models

# %%
from sklearn.ensemble import RandomForestRegressor

#from sklearn.linear_model import LinearRegression
#from sklearn.linear_model import Lasso
#from sklearn.linear_model import Ridge
#from sklearn.linear_model import ElasticNet
#from sklearn.linear_model import HuberRegressor
#from sklearn.linear_model import Lars
#from sklearn.linear_model import LassoLars
#from sklearn.linear_model import PassiveAggressiveRegressor
#from sklearn.linear_model import RANSACRegressor
#from sklearn.linear_model import SGDRegressor

#from sklearn.ensemble import AdaBoostRegressor
#from sklearn.neural_network import MLPRegressor
#from sklearn.tree import DecisionTreeRegressor
#from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# Imports the standard error metric functions of Variance (explained variance), MAE, MSE and R2 from the SciKit Learn library.
#
# Explained variance is an indicator of whether the model is accounting for the variance in the dataset.
#
# MAE - is the real error averaged across the predicted values.
#
# MSE - is the square of the mean error, which indicates risk and the quality of the prediction. Values closer to zero are better.
#
# R squared or R2 'represents the proportion of variance (of y) that has been explained by the independent variables in the model. It provides an indication of goodness of fit and therefore a measure of how well unseen samples are likely to be predicted by the model, through the proportion of explained variance.'1 An R2 value closer to 1 indicates a good fit.
#
# 1 - https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics

# %%
#Import Error Metrics

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
#Import Test/Train split function

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2.3.2 Import Data & Split into Train/Test Data

# %% [markdown]
# The train_test_split function allows you to defined test_size and train_size, if one isn't specified it is set as the complementary value.
#
# A training size of 0.75-0.8 is generally recommended. Sensitivity testing to the training size showed continuous improvement with a larger training size. Beyond 80% of the data for training may lead to overfitting hence selection at this point.
#
# Defining the random_state with an integer allows repetition across different Notebooks/model runs.

# %%
#Read in datafile

# %%
df_LSOA_Location_Energy_Sales = pd.read_csv('1_DataCleaning/LSOA_Location_Energy_Sales.csv')

# %% [markdown]
# ## 2.3.2.1 Selecting a subset of the UK dataset by Local Authority

# %% [markdown]
# Run a subset of the data by Local Authority.

# %%
df_LSOA_Location_Energy_Sales = df_LSOA_Location_Energy_Sales[df_LSOA_Location_Energy_Sales['Local authority name'].isin(['Pembrokeshire', 'Carmarthenshire', 'Ceredigion', 'Gwynedd', 'Conwy', 'Powys'])]

# %%
df_LSOA_Location_Energy_Sales.describe()
# Out:
#          Unnamed: 0              X              Y   Unnamed: 0.1  \
# count   4068.000000    4068.000000    4068.000000    4068.000000
# mean   33811.723451  258782.620987  275323.442653  398900.438053
# std      567.214273   35425.544199   66162.256125    3745.216091
# min    32899.000000  175525.902000  198927.456000  394500.000000
# 25%    33347.750000  240850.423250  213663.565500  395629.500000
# 50%    33781.000000  258236.147500  251735.395000  399079.000000
# 75%    34317.250000  281974.745250  340191.625500  400208.500000
# max    34749.000000  331724.993000  382454.355000  412938.000000
#
#        Total_number_of_domestic_electricity_meters  \
# count                                  4068.000000
# mean                                    786.106686
# std                                     200.395166
# min                                     407.000000
# 25%                                     635.000000
# 50%                                     760.000000
# 75%                                     914.000000
# max                                    1785.000000
#
#        Total_domestic_electricity_consumption_kWh  \
# count                                4.068000e+03
# mean                                 3.223095e+06
# std                                  1.008866e+06
# min                                  1.362058e+06
# 25%                                  2.473514e+06
# 50%                                  3.069661e+06
# 75%                                  3.798325e+06
# max                                  8.595643e+06
#
#        Mean_domestic_electricity_consumption_kWh_per_meter  \
# count                                        4068.000000
# mean                                         4128.377021
# std                                           854.846591
# min                                          2152.317609
# 25%                                          3420.803859
# 50%                                          3954.871224
# 75%                                          4823.760183
# max                                          8436.973458
#
#        Median_domestic_electricity_consumption_kWh_per_meter         Year  \
# count                                        4068.000000      4068.000000
# mean                                         3289.177870      2014.000000
# std                                           587.744907         2.582306
# min                                          1681.900000      2010.000000
# 25%                                          2848.150000      2012.000000
# 50%                                          3194.625000      2014.000000
# 75%                                          3719.837500      2016.000000
# max                                          6988.300000      2018.000000
#
#        Ratio_Consumption_per_Meter  Mean_price_paid
# count                  4068.000000      4068.000000
# mean                   4128.377317    163573.952881
# std                     854.845038     48805.338782
# min                    2152.317610         0.000000
# 25%                    3420.803859    129523.182272
# 50%                    3954.871224    160849.184559
# 75%                    4823.760183    194489.885914
# max                    8436.973458    405533.025200

# %%
#Split df_LSOA_Location_Energy_Sales dataset 80:20

# %%
train, test = train_test_split(df_LSOA_Location_Energy_Sales, test_size=0.2, train_size=0.8, random_state=10)

# %%
df_test = test

# %%
df_test
# Out:
#         Unnamed: 0           X           Y  LSOA code  Unnamed: 0.1  \
# 298930       33427  271303.328  214298.937  W01000718      400954.0
# 293185       33725  248259.273  360024.172  W01000054      394571.0
# 297480       33763  197539.044  207990.376  W01000554      399343.0
# 293850       33139  277455.079  377006.979  W01000131      395310.0
# 293858       33139  277455.079  377006.979  W01000131      395318.0
# 294179       33722  278102.617  381991.107  W01000169      395675.0
# 293623       34422  247078.291  353161.880  W01000104      395057.0
# 294211       33556  281390.658  381196.005  W01000173      395711.0
# 298589       33022  262387.195  214463.187  W01000680      400575.0
# 293907       33133  280473.463  369272.564  W01000137      395373.0
# 298241       33492  241888.931  220802.158  W01000638      400188.0
# 296851       34299  322344.792  296769.862  W01000476      398644.0
# 297067       32955  299329.269  231466.040  W01000503      398884.0
# 298188       33489  244801.301  200738.782  W01000633      400130.0
# 297803       34286  189608.105  205679.265  W01000590      399702.0
# 298039       34319  213336.547  205038.929  W01000616      399964.0
# 298351       33818  252776.135  201214.016  W01000651      400311.0
# 294165       33721  277737.706  381459.653  W01000168      395660.0
# 297490       33764  191727.904  219168.141  W01000555      399354.0
# 309593       32966  251430.589  198927.456  W01001924      412802.0
# 298018       34323  183385.853  207342.556  W01000614      399941.0
# 293658       34432  237467.793  335207.290  W01000108      395096.0
# 297324       34092  260231.986  251880.249  W01000537      399170.0
# 298444       34531  247971.722  208282.306  W01000662      400414.0
# 309700       34291  259884.515  281891.702  W01001936      412921.0
# 293722       33333  260470.643  367730.837  W01000115      395167.0
# 296497       33963  313164.614  237739.516  W01000430      398251.0
# 298629       33012  244535.747  235772.607  W01000685      400620.0
# 298192       33489  244801.301  200738.782  W01000633      400134.0
# 298021       34323  183385.853  207342.556  W01000614      399944.0
# ...            ...         ...         ...        ...           ...
# 294336       34419  278410.745  381152.576  W01000187      395850.0
# 297380       33955  270042.596  279528.913  W01000543      399232.0
# 296516       33961  303657.758  251022.175  W01000432      398272.0
# 297354       33956  251453.388  266962.306  W01000540      399203.0
# 293349       33349  258210.589  331780.949  W01000074      394753.0
# 297988       34726  211807.756  200462.023  W01000610      399907.0
# 296782       32973  295502.690  284061.574  W01000466      398567.0
# 293396       33356  258525.176  327336.478  W01000079      394805.0
# 297303       34093  259143.334  278007.979  W01000534      399146.0
# 298718       34326  242287.024  219240.288  W01000694      400718.0
# 296826       34304  275011.653  300938.603  W01000473      398616.0
# 294341       34419  278410.745  381152.576  W01000187      395855.0
# 297433       33959  264767.007  284180.024  W01000549      399291.0
# 297329       34092  260231.986  251880.249  W01000537      399175.0
# 293315       33353  234375.798  336298.227  W01000070      394715.0
# 294118       33719  296207.709  366252.272  W01000162      395607.0
# 293885       33134  280159.816  361502.885  W01000134      395348.0
# 298462       34529  256755.550  213791.315  W01000664      400434.0
# 298015       34329  215978.916  245786.749  W01000613      399937.0
# 297811       34284  189291.193  206284.214  W01000591      399711.0
# 293857       33139  277455.079  377006.979  W01000131      395317.0
# 298476       34527  257836.587  203619.158  W01000666      400450.0
# 298921       33414  249786.842  211626.651  W01000717      400944.0
# 293379       33348  258623.017  372543.186  W01000077      394786.0
# 297843       34278  190401.326  206344.470  W01000594      399746.0
# 309687       34293  258802.006  282144.644  W01001934      412906.0
# 298341       33817  264749.368  240655.322  W01000650      400300.0
# 298131       33650  262792.118  212409.818  W01000626      400066.0
# 297602       34474  194175.234  237982.979  W01000567      399478.0
# 294215       33556  281390.658  381196.005  W01000173      395715.0
#
#        Local authority name Local authority code            MSOA name  \
# 298930      Carmarthenshire            W06000010  Carmarthenshire 010
# 293185              Gwynedd            W06000002          Gwynedd 007
# 297480        Pembrokeshire            W06000009    Pembrokeshire 009
# 293850                Conwy            W06000003            Conwy 012
# 293858                Conwy            W06000003            Conwy 012
# 294179                Conwy            W06000003            Conwy 001
# 293623              Gwynedd            W06000002          Gwynedd 008
# 294211                Conwy            W06000003            Conwy 003
# 298589      Carmarthenshire            W06000010  Carmarthenshire 011
# 293907                Conwy            W06000003            Conwy 015
# 298241      Carmarthenshire            W06000010  Carmarthenshire 007
# 296851                Powys            W06000023            Powys 005
# 297067                Powys            W06000023            Powys 020
# 298188      Carmarthenshire            W06000010  Carmarthenshire 021
# 297803        Pembrokeshire            W06000009    Pembrokeshire 012
# 298039        Pembrokeshire            W06000009    Pembrokeshire 011
# 298351      Carmarthenshire            W06000010  Carmarthenshire 020
# 294165                Conwy            W06000003            Conwy 002
# 297490        Pembrokeshire            W06000009    Pembrokeshire 008
# 309593      Carmarthenshire            W06000010  Carmarthenshire 026
# 298018        Pembrokeshire            W06000009    Pembrokeshire 008
# 293658              Gwynedd            W06000002          Gwynedd 012
# 297324           Ceredigion            W06000008       Ceredigion 008
# 298444      Carmarthenshire            W06000010  Carmarthenshire 016
# 309700           Ceredigion            W06000008       Ceredigion 003
# 293722              Gwynedd            W06000002          Gwynedd 003
# 296497                Powys            W06000023            Powys 015
# 298629      Carmarthenshire            W06000010  Carmarthenshire 001
# 298192      Carmarthenshire            W06000010  Carmarthenshire 021
# 298021        Pembrokeshire            W06000009    Pembrokeshire 008
# ...                     ...                  ...                  ...
# 294336                Conwy            W06000003            Conwy 002
# 297380           Ceredigion            W06000008       Ceredigion 011
# 296516                Powys            W06000023            Powys 014
# 297354           Ceredigion            W06000008       Ceredigion 005
# 293349              Gwynedd            W06000002          Gwynedd 013
# 297988        Pembrokeshire            W06000009    Pembrokeshire 016
# 296782                Powys            W06000023            Powys 010
# 293396              Gwynedd            W06000002          Gwynedd 013
# 297303           Ceredigion            W06000008       Ceredigion 011
# 298718      Carmarthenshire            W06000010  Carmarthenshire 008
# 296826                Powys            W06000023            Powys 004
# 294341                Conwy            W06000003            Conwy 002
# 297433           Ceredigion            W06000008       Ceredigion 001
# 297329           Ceredigion            W06000008       Ceredigion 008
# 293315              Gwynedd            W06000002          Gwynedd 012
# 294118                Conwy            W06000003            Conwy 014
# 293885                Conwy            W06000003            Conwy 015
# 298462      Carmarthenshire            W06000010  Carmarthenshire 016
# 298015        Pembrokeshire            W06000009    Pembrokeshire 001
# 297811        Pembrokeshire            W06000009    Pembrokeshire 012
# 293857                Conwy            W06000003            Conwy 012
# 298476      Carmarthenshire            W06000010  Carmarthenshire 017
# 298921      Carmarthenshire            W06000010  Carmarthenshire 016
# 293379              Gwynedd            W06000002          Gwynedd 001
# 297843        Pembrokeshire            W06000009    Pembrokeshire 012
# 309687           Ceredigion            W06000008       Ceredigion 002
# 298341      Carmarthenshire            W06000010  Carmarthenshire 002
# 298131      Carmarthenshire            W06000010  Carmarthenshire 013
# 297602        Pembrokeshire            W06000009    Pembrokeshire 002
# 294215                Conwy            W06000003            Conwy 003
#
#         MSOA code             LSOA name  \
# 298930  W02000151  Carmarthenshire 010D
# 293185  W02000016          Gwynedd 007A
# 297480  W02000134    Pembrokeshire 009A
# 293850  W02000038            Conwy 012D
# 293858  W02000038            Conwy 012D
# 294179  W02000027            Conwy 001D
# 293623  W02000017          Gwynedd 008C
# 294211  W02000029            Conwy 003B
# 298589  W02000152  Carmarthenshire 011A
# 293907  W02000041            Conwy 015C
# 298241  W02000148  Carmarthenshire 007B
# 296851  W02000101            Powys 005C
# 297067  W02000414            Powys 020C
# 298188  W02000162  Carmarthenshire 021B
# 297803  W02000137    Pembrokeshire 012B
# 298039  W02000136    Pembrokeshire 011F
# 298351  W02000161  Carmarthenshire 020A
# 294165  W02000028            Conwy 002B
# 297490  W02000133    Pembrokeshire 008A
# 309593  W02000167  Carmarthenshire 026H
# 298018  W02000133    Pembrokeshire 008D
# 293658  W02000021          Gwynedd 012D
# 297324  W02000123       Ceredigion 008D
# 298444  W02000157  Carmarthenshire 016A
# 309700  W02000118       Ceredigion 003F
# 293722  W02000012          Gwynedd 003E
# 296497  W02000111            Powys 015A
# 298629  W02000142  Carmarthenshire 001A
# 298192  W02000162  Carmarthenshire 021B
# 298021  W02000133    Pembrokeshire 008D
# ...           ...                   ...
# 294336  W02000028            Conwy 002C
# 297380  W02000421       Ceredigion 011C
# 296516  W02000110            Powys 014B
# 297354  W02000120       Ceredigion 005E
# 293349  W02000022          Gwynedd 013B
# 297988  W02000141    Pembrokeshire 016A
# 296782  W02000106            Powys 010C
# 293396  W02000022          Gwynedd 013C
# 297303  W02000421       Ceredigion 011B
# 298718  W02000149  Carmarthenshire 008D
# 296826  W02000100            Powys 004C
# 294341  W02000028            Conwy 002C
# 297433  W02000116       Ceredigion 001E
# 297329  W02000123       Ceredigion 008D
# 293315  W02000021          Gwynedd 012A
# 294118  W02000040            Conwy 014C
# 293885  W02000041            Conwy 015B
# 298462  W02000157  Carmarthenshire 016C
# 298015  W02000126    Pembrokeshire 001E
# 297811  W02000137    Pembrokeshire 012C
# 293857  W02000038            Conwy 012D
# 298476  W02000158  Carmarthenshire 017B
# 298921  W02000157  Carmarthenshire 016E
# 293379  W02000010          Gwynedd 001C
# 297843  W02000137    Pembrokeshire 012E
# 309687  W02000117       Ceredigion 002F
# 298341  W02000143  Carmarthenshire 002B
# 298131  W02000154  Carmarthenshire 013B
# 297602  W02000127    Pembrokeshire 002D
# 294215  W02000029            Conwy 003B
#
#         Total_number_of_domestic_electricity_meters  \
# 298930                                        676.0
# 293185                                        472.0
# 297480                                        790.0
# 293850                                        640.0
# 293858                                        678.0
# 294179                                       1002.0
# 293623                                        874.0
# 294211                                        701.0
# 298589                                        900.0
# 293907                                        655.0
# 298241                                        520.0
# 296851                                        637.0
# 297067                                        443.0
# 298188                                        781.0
# 297803                                        621.0
# 298039                                        854.0
# 298351                                        722.0
# 294165                                        813.0
# 297490                                        611.0
# 309593                                        665.0
# 298018                                        774.0
# 293658                                       1187.0
# 297324                                        638.0
# 298444                                        994.0
# 309700                                        438.0
# 293722                                        930.0
# 296497                                        589.0
# 298629                                        677.0
# 298192                                        782.0
# 298021                                        781.0
# ...                                             ...
# 294336                                        650.0
# 297380                                        967.0
# 296516                                        570.0
# 297354                                        598.0
# 293349                                       1244.0
# 297988                                        827.0
# 296782                                        631.0
# 293396                                        678.0
# 297303                                        680.0
# 298718                                        632.0
# 296826                                       1110.0
# 294341                                        658.0
# 297433                                        745.0
# 297329                                        640.0
# 293315                                        612.0
# 294118                                        717.0
# 293885                                       1018.0
# 298462                                        897.0
# 298015                                       1209.0
# 297811                                        498.0
# 293857                                        674.0
# 298476                                        663.0
# 298921                                        710.0
# 293379                                        615.0
# 297843                                       1074.0
# 309687                                       1114.0
# 298341                                        651.0
# 298131                                        823.0
# 297602                                       1006.0
# 294215                                        709.0
#
#         Total_domestic_electricity_consumption_kWh  \
# 298930                                 2354054.000
# 293185                                 2102392.500
# 297480                                 3968741.300
# 293850                                 2406385.900
# 293858                                 2045810.700
# 294179                                 3344453.738
# 293623                                 3057817.000
# 294211                                 2851320.100
# 298589                                 3888123.600
# 293907                                 3758261.000
# 298241                                 1684259.100
# 296851                                 3592140.000
# 297067                                 2537100.000
# 298188                                 2164890.500
# 297803                                 2037000.000
# 298039                                 3036214.000
# 298351                                 2337697.500
# 294165                                 3022964.400
# 297490                                 2802631.000
# 309593                                 1866385.300
# 298018                                 3466874.800
# 293658                                 4009260.200
# 297324                                 3466376.900
# 298444                                 3608476.000
# 309700                                 2413025.600
# 293722                                 4063469.350
# 296497                                 2911139.700
# 298629                                 3136245.000
# 298192                                 2127678.000
# 298021                                 3510148.000
# ...                                            ...
# 294336                                 2291098.000
# 297380                                 6150426.200
# 296516                                 1968914.400
# 297354                                 3267755.300
# 293349                                 6637989.900
# 297988                                 3316950.200
# 296782                                 2250450.300
# 293396                                 3560955.600
# 297303                                 3466092.900
# 298718                                 2361093.167
# 296826                                 4366071.233
# 294341                                 2255983.838
# 297433                                 6122581.800
# 297329                                 3220404.900
# 293315                                 3101701.050
# 294118                                 3793740.000
# 293885                                 3119737.652
# 298462                                 3977811.000
# 298015                                 5299294.200
# 297811                                 2027240.200
# 293857                                 2201526.117
# 298476                                 2163545.800
# 298921                                 2268527.000
# 293379                                 1774378.200
# 297843                                 3260233.900
# 309687                                 4467213.700
# 298341                                 3247941.500
# 298131                                 2366340.100
# 297602                                 3175241.800
# 294215                                 2829079.000
#
#         Mean_domestic_electricity_consumption_kWh_per_meter  \
# 298930                                        3482.000000
# 293185                                        4454.221398
# 297480                                        5023.723165
# 293850                                        3759.977969
# 293858                                        3017.419912
# 294179                                        3337.778181
# 293623                                        3498.646453
# 294211                                        4067.503709
# 298589                                        4320.137333
# 293907                                        5737.803053
# 298241                                        3238.959808
# 296851                                        5639.000000
# 297067                                        5727.000000
# 298188                                        2771.946863
# 297803                                        3280.193237
# 298039                                        3555.000000
# 298351                                        3237.808172
# 294165                                        3718.283395
# 297490                                        4587.000000
# 309593                                        2806.594436
# 298018                                        4479.166408
# 293658                                        3377.641281
# 297324                                        5433.192633
# 298444                                        3630.000000
# 309700                                        5509.190868
# 293722                                        4369.321882
# 296497                                        4942.512224
# 298629                                        4632.562777
# 298192                                        2721.000000
# 298021                                        4494.000000
# ...                                                   ...
# 294336                                        3524.766154
# 297380                                        6360.316649
# 296516                                        3454.235790
# 297354                                        5464.473746
# 293349                                        5336.004743
# 297988                                        4010.822491
# 296782                                        3566.482250
# 293396                                        5252.146903
# 297303                                        5097.195441
# 298718                                        3735.906909
# 296826                                        3933.397508
# 294341                                        3428.546866
# 297433                                        8218.230604
# 297329                                        5031.882656
# 293315                                        5068.138971
# 294118                                        5291.129707
# 293885                                        3064.575297
# 298462                                        4435.000000
# 298015                                        4383.204467
# 297811                                        4070.763454
# 293857                                        3266.359224
# 298476                                        3263.266667
# 298921                                        3195.000000
# 293379                                        2885.167805
# 297843                                        3035.599535
# 309687                                        4010.066158
# 298341                                        4989.157450
# 298131                                        2875.261361
# 297602                                        3156.303976
# 294215                                        3990.238364
#
#         Median_domestic_electricity_consumption_kWh_per_meter    Year  \
# 298930                                            3080.00      2014.0
# 293185                                            3719.45      2011.0
# 297480                                            4311.25      2013.0
# 293850                                            3273.90      2010.0
# 293858                                            2696.20      2018.0
# 294179                                            2301.10      2015.0
# 293623                                            2807.25      2017.0
# 294211                                            3194.00      2011.0
# 298589                                            3432.05      2015.0
# 293907                                            4361.80      2013.0
# 298241                                            2825.30      2018.0
# 296851                                            4115.00      2014.0
# 297067                                            4286.00      2014.0
# 298188                                            2195.90      2010.0
# 297803                                            2926.10      2012.0
# 298039                                            2424.00      2014.0
# 298351                                            2804.55      2011.0
# 294165                                            3185.30      2010.0
# 297490                                            3744.00      2014.0
# 309593                                            2455.90      2012.0
# 298018                                            3608.20      2011.0
# 293658                                            2650.80      2016.0
# 297324                                            4364.85      2010.0
# 298444                                            2943.00      2014.0
# 309700                                            3919.20      2011.0
# 293722                                            3563.55      2017.0
# 296497                                            3595.90      2011.0
# 298629                                            3612.30      2010.0
# 298192                                            2357.00      2014.0
# 298021                                            3415.00      2014.0
# ...                                                   ...         ...
# 294336                                            3200.70      2010.0
# 297380                                            4501.00      2012.0
# 296516                                            2948.70      2012.0
# 297354                                            4067.20      2013.0
# 293349                                            4211.70      2013.0
# 297988                                            2914.90      2017.0
# 296782                                            2721.80      2017.0
# 293396                                            3806.80      2015.0
# 297303                                            3944.65      2016.0
# 298718                                            2889.10      2018.0
# 296826                                            3054.05      2016.0
# 294341                                            3071.95      2015.0
# 297433                                            6779.30      2011.0
# 297329                                            3947.75      2015.0
# 293315                                            4201.60      2015.0
# 294118                                            3981.90      2017.0
# 293885                                            2501.45      2018.0
# 298462                                            3565.00      2014.0
# 298015                                            3048.00      2017.0
# 297811                                            3519.20      2011.0
# 293857                                            2776.00      2017.0
# 298476                                            2888.60      2010.0
# 298921                                            2768.00      2014.0
# 293379                                            2366.00      2016.0
# 297843                                            2587.00      2016.0
# 309687                                            2960.40      2016.0
# 298341                                            4116.20      2010.0
# 298131                                            2436.60      2016.0
# 297602                                            2671.70      2018.0
# 294215                                            3118.20      2015.0
#
#         Ratio_Consumption_per_Meter  Mean_price_paid
# 298930                  3482.328402     82854.062500
# 293185                  4454.221398    122695.833335
# 297480                  5023.723165    213883.170833
# 293850                  3759.977969    146431.109852
# 293858                  3017.419912    213943.442573
# 294179                  3337.778182    155560.029760
# 293623                  3498.646453    110875.568183
# 294211                  4067.503709    135308.026620
# 298589                  4320.137333    154332.900190
# 293907                  5737.803053    199751.189062
# 298241                  3238.959808    114833.928571
# 296851                  5639.152276    231517.530633
# 297067                  5727.088036    245364.468343
# 298188                  2771.946863    120352.878787
# 297803                  3280.193237    140699.404763
# 298039                  3555.285714    257685.469907
# 298351                  3237.808172     96496.392496
# 294165                  3718.283395    126633.143940
# 297490                  4586.957447    249726.736110
# 309593                  2806.594436     52066.808036
# 298018                  4479.166408    157255.833335
# 293658                  3377.641281    147851.662580
# 297324                  5433.192633    174065.634675
# 298444                  3630.257545    163799.973643
# 309700                  5509.190868    218447.556090
# 293722                  4369.321882    195996.826702
# 296497                  4942.512224    195620.753205
# 298629                  4632.562777    144735.416667
# 298192                  2720.815857     93570.731356
# 298021                  4494.427657    219611.721615
# ...                             ...              ...
# 294336                  3524.766154     26822.500000
# 297380                  6360.316649    154216.602272
# 296516                  3454.235789    185354.891100
# 297354                  5464.473746    140520.133928
# 293349                  5336.004743    151597.818853
# 297988                  4010.822491    280248.104535
# 296782                  3566.482250    137547.524555
# 293396                  5252.146903    201778.420140
# 297303                  5097.195441    239058.281250
# 298718                  3735.906910    211626.131107
# 296826                  3933.397507    127618.972685
# 294341                  3428.546866     95947.172619
# 297433                  8218.230604    164173.103985
# 297329                  5031.882656    183850.568182
# 293315                  5068.138971    201523.622815
# 294118                  5291.129707    213512.964465
# 293885                  3064.575297    155678.817830
# 298462                  4434.571906    138157.487037
# 298015                  4383.204467    202971.565338
# 297811                  4070.763454    120938.492062
# 293857                  3266.359224    229730.355625
# 298476                  3263.266667    115243.327245
# 298921                  3195.108451    124906.413920
# 293379                  2885.167805    123128.223475
# 297843                  3035.599534     94048.328951
# 309687                  4010.066158    197566.670140
# 298341                  4989.157450    162074.053032
# 298131                  2875.261361    124629.651590
# 297602                  3156.303976    147375.959742
# 294215                  3990.238364    150362.185897
#
# [814 rows x 17 columns]

# %% [markdown]
# ## 2.3.3 Model Set-up, Training, Prediction & Evaluation

# %% [markdown]
# The model function undertakes the following steps:
#
# 1. The model is defined, taking the feature variables and hyperparameters as arguments.
#
# 2. The model is trained using .fit on the specified training data.
#
# 3. The model is run using .predict on the feature variables.
#
# 4. Evaluation metrics are printed to screen, stored in a dataframe and plotted (against number of neighbors).
#
# The function returns the dataframe of evaluation metrics.

# %%
max_depth = [5, 10, 15, 20, 25, 30, 35, 40]

# %%
def RandomForest(feature_variables, n_estimators, criterion, max_depth, random_state):
         
    #Define empty dataframe
    df_Results = None
    
    #Fit & Run model
    for d in max_depth:
        #Define the model
        regr = RandomForestRegressor(n_estimators=n_estimators, criterion=criterion, max_depth=d, random_state=random_state)
            
        #Set the training data
        x_train = np.asanyarray(train[feature_variables])
        y_train = np.asanyarray(train[['Mean_domestic_electricity_consumption_kWh_per_meter']])
        
        #Train the model on the set training data
        regr.fit(x_train, y_train.ravel())
        
        #Predict results using the trained model and the previously defined test data
        y_hat = regr.predict(test[feature_variables])
    
        x_test = np.asanyarray(test[feature_variables[0]])
        y_test = np.asanyarray(test[['Mean_domestic_electricity_consumption_kWh_per_meter']])
        
        #Check the shape of the data
        y_test = np.squeeze(y_test)
        y_test.shape
        
        #Run evaluation metrics to check the model performance & print results to notebook
        print("RandomForest: max_depth=%.2f" % d, feature_variables)
        print("Explained Variance Score: %.2f" % explained_variance_score(y_test, y_hat))
        print("MAE: %.2f" % mean_absolute_error(y_test, y_hat))
        print("MSE: %.2f" % mean_squared_error(y_test, y_hat))
        print("R2-score: %.2f" % r2_score(y_test, y_hat))
        print(" ")
        
        #Plot the results
        plt.figure()
        plt.scatter(x_test, y_test, s=5, edgecolor="black", c="black", label="data")
        plt.plot(x_test, y_hat, color="cornflowerblue", label="max_depth=%.2f" % d, linewidth=1)
        plt.xlabel("data")
        plt.ylabel("target")
        plt.title("Decision Tree Regression")
        plt.legend()
        plt.show()
        
        #Set up temporary results df
        df = None
        df = pd.DataFrame({'Explained Variance Score': [explained_variance_score(y_test, y_hat)]},
                  index=["RandomForest: max_depth=%.2f" % d])
        df.insert(1,'MAE', mean_absolute_error(y_test, y_hat))
        df.insert(2,'MSE', mean_squared_error(y_test, y_hat))
        df.insert(3,'R2_score', r2_score(y_test, y_hat))
        df.insert(0, 'Model', 'RandomForest')
        df.insert(1, 'max_depth', d)
        df.insert(2, 'Feature Variables', [feature_variables])                          
        
        #Add each df to master df
        if df_Results is None:
            df_Results = df
        else:
            df_Results = pd.concat([df_Results, df], axis=0)                   
    
    #Plot learning curve of R2_score
    plt.scatter(df_Results.max_depth, df_Results.R2_score)
    plt.xlabel("max_depth")
    plt.ylabel("R2_score")
    plt.title("Random Forest Learning Curve - R2")
    plt.show()

    #Plot learning curve of MAE
    plt.scatter(df_Results.max_depth, df_Results.MAE)
    plt.xlabel("max_depth")
    plt.ylabel("MAE")
    plt.title("Random Forest Learning Curve - MAE")
    plt.show()
    
    return df_Results

# %% [markdown]
# ## 2.3.3.1 - Model Training & Evaluation (Feature Variables = Mean Price Paid, Year)

# %% [markdown]
# In the first instance 'Year' and 'Mean Price Paid' are selected as feature variables to predict 'Mean_domestic_electricity_consumption_kWh_per_meter'.
#
# This model is expected to predict with a better fit relatively than the linear models where either 'Year' or 'Mean Price Paid' were taken as the sole feature variable as plotting of the data shows a (weak) positive correlation. From the previous simple linear model runs it is expected that 'Mean Price Paid' is the more dominant feature variable, but there is expected to be some degree of annual correlation that together could provide a better fit model.
#
# The Random Forest algorithm may be better at handling the variance in the data set but is still not expected to have an objectively good fit when only the above two feature variables are selected.
#
# As many factors affect electricity consumption it is expected that either a greater number of feature variables (or a model better able to deal with variance/complexity in the data) will provide a better fit. Noting that Random Forest is hypothesized to be one of the algorithms better able to fit to the dataset.

# %% [markdown]
# Random Forest has several hyperparameters that are used to refine the model. The hyperparameters varied within the below model runs are:
#
# 1. Number of estimators - which is the number of trees in the forest, the default is set to 100 and increasing substantially has a knock on to run time.
# 2. Criterion - whether the model averages based on MSE or MAE. MSE is substantially faster, with MAE throwing runtime and memory issues. Whilst MAE could be a better predictor this has therefore not been explored.
# 3. Maximum depth of the tree - aka number of branches - the default is none with the model running until pure. The below runs through a series of model runs over a range of max_depth between 5 to 30, and none, to determine which max_depth provides the best fit model.
# 4. Random State - It is not known the impact of this hyperparameter so a series of runs have again been trialled, on this occasion set to zero.
#
# All other hyperparameters are not specified and set to the default values.

# %%
max_depth = [5, 10, 15, 20, 25, 30, 35, 40]

# %%
df_Results_1 = RandomForest(['Mean_price_paid','Year'], 100, 'mse', max_depth, 0)
# Out:
# RandomForest: max_depth=5.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.33
# MAE: 547.51
# MSE: 503612.32
# R2-score: 0.33
# RandomForest: max_depth=10.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.30
# MAE: 560.49
# MSE: 530827.25
# R2-score: 0.30
# RandomForest: max_depth=15.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.23
# MAE: 584.64
# MSE: 577890.13
# R2-score: 0.23
# RandomForest: max_depth=20.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.20
# MAE: 596.32
# MSE: 604504.66
# R2-score: 0.20
# RandomForest: max_depth=25.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.19
# MAE: 599.84
# MSE: 611295.75
# R2-score: 0.19
# RandomForest: max_depth=30.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.19
# MAE: 600.25
# MSE: 612877.68
# R2-score: 0.19
# RandomForest: max_depth=35.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.19
# MAE: 600.68
# MSE: 613442.16
# R2-score: 0.19
# RandomForest: max_depth=40.00 ['Mean_price_paid', 'Year']
# Explained Variance Score: 0.19
# MAE: 600.69
# MSE: 613570.05
# R2-score: 0.19

# %%
df_Results_1
# Out:
#                                       Model  max_depth  \
# RandomForest: max_depth=5.00   RandomForest          5
# RandomForest: max_depth=10.00  RandomForest         10
# RandomForest: max_depth=15.00  RandomForest         15
# RandomForest: max_depth=20.00  RandomForest         20
# RandomForest: max_depth=25.00  RandomForest         25
# RandomForest: max_depth=30.00  RandomForest         30
# RandomForest: max_depth=35.00  RandomForest         35
# RandomForest: max_depth=40.00  RandomForest         40
#
#                                      Feature Variables  \
# RandomForest: max_depth=5.00   [Mean_price_paid, Year]
# RandomForest: max_depth=10.00  [Mean_price_paid, Year]
# RandomForest: max_depth=15.00  [Mean_price_paid, Year]
# RandomForest: max_depth=20.00  [Mean_price_paid, Year]
# RandomForest: max_depth=25.00  [Mean_price_paid, Year]
# RandomForest: max_depth=30.00  [Mean_price_paid, Year]
# RandomForest: max_depth=35.00  [Mean_price_paid, Year]
# RandomForest: max_depth=40.00  [Mean_price_paid, Year]
#
#                                Explained Variance Score         MAE  \
# RandomForest: max_depth=5.00                   0.332245  547.507166
# RandomForest: max_depth=10.00                  0.296106  560.493570
# RandomForest: max_depth=15.00                  0.233705  584.638277
# RandomForest: max_depth=20.00                  0.198456  596.319298
# RandomForest: max_depth=25.00                  0.189453  599.839660
# RandomForest: max_depth=30.00                  0.187357  600.249228
# RandomForest: max_depth=35.00                  0.186609  600.675673
# RandomForest: max_depth=40.00                  0.186439  600.693571
#
#                                          MSE  R2_score
# RandomForest: max_depth=5.00   503612.322763  0.332177
# RandomForest: max_depth=10.00  530827.246913  0.296088
# RandomForest: max_depth=15.00  577890.128554  0.233680
# RandomForest: max_depth=20.00  604504.656373  0.198387
# RandomForest: max_depth=25.00  611295.752586  0.189381
# RandomForest: max_depth=30.00  612877.676360  0.187284
# RandomForest: max_depth=35.00  613442.162578  0.186535
# RandomForest: max_depth=40.00  613570.049060  0.186366

# %% [markdown]
# Explained Variance - peaks at 0.33 with a max_depth of 5. This is higher than achieved over the linear or kNN algorithms. But the model still does not deal with the variance in the model.
#
# MAE - the MAE is marginally improved over the equivalent kNN model runs and linear models.
#
# MSE - is still high, reflecting a high risk of a low quality prediction.
#
# R2 - is 0.33, demonstrating the model 'fit' is still poor.

# %% [markdown]
# CONCLUSION:
#
# Overall the Random Forest algorithm with feature variables of 'mean price paid', 'year', performs best overall compared to kNN and linear model equivalent runs. A max_depth of 5 appears to provide the optimum achievable fit with these feature variables.
#
# However, an R2 score of 0.33 and a MAE of still >10% compared to the mean for the data set is still not a good enough fit to use the model in earnest. Further improvements through further model refinments, additional possible feature variables or alternative models would be required.

# %%
#Export results to csv

# %%
df_Results_1.to_csv('2_ModelResults/RandomForest_Results_WalesRural_1.csv')

# %% [markdown]
# ## 2.3.3.2 - Model Training & Evaluation (Feature Variables = Mean Price Paid, Year, X, Y)

# %% [markdown]
# Location as a feature variable is expected to improve the model and support better management of the variance in the data set.
#
# Location is denoted by two feature variables 'X' and 'Y' which represent the X, Y OS Coordinates of the population weighted centroid for each LSOA. Both are therefore implemented within the same model run.

# %% [markdown]
# The hyperparameters varied within the below model runs are:
#
# 1. Number of estimators - which is the number of trees in the forest, the default is set to 100 and increasing substantially has a knock on to run time.
# 2. Criterion - whether the model averages based on MSE or MAE. MSE is substantially faster, with MAE throwing runtime and memory issues. Whilst MAE could be a better predictor this has therefore not been explored.
# 3. Maximum depth of the tree - aka number of branches - the default is none with the model running until pure. The below runs through a series of model runs over a range of max_depth between 5 to 40, and none, to determine which max_depth provides the best fit model.
# 4. Random State - It is not known the impact of this hyperparameter so a series of runs have again been trialled, on this occasion set to zero.
#
# All other hyperparameters are not specified and set to the default values.

# %%
max_depth = [5, 10, 15, 20, 25, 30, 35, 40]

# %%
df_Results_2 = RandomForest(['Mean_price_paid','Year', 'X', 'Y'], 100, 'mse', max_depth, 0)
# Out:
# RandomForest: max_depth=5.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.53
# MAE: 437.66
# MSE: 353052.89
# R2-score: 0.53
# RandomForest: max_depth=10.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.76
# MAE: 298.25
# MSE: 180637.84
# R2-score: 0.76
# RandomForest: max_depth=15.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.82
# MAE: 246.06
# MSE: 136305.98
# R2-score: 0.82
# RandomForest: max_depth=20.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.83
# MAE: 239.78
# MSE: 131779.87
# R2-score: 0.83
# RandomForest: max_depth=25.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.83
# MAE: 238.64
# MSE: 131069.36
# R2-score: 0.83
# RandomForest: max_depth=30.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.83
# MAE: 238.66
# MSE: 130720.89
# R2-score: 0.83
# RandomForest: max_depth=35.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.83
# MAE: 238.72
# MSE: 130846.39
# R2-score: 0.83
# RandomForest: max_depth=40.00 ['Mean_price_paid', 'Year', 'X', 'Y']
# Explained Variance Score: 0.83
# MAE: 238.72
# MSE: 130846.39
# R2-score: 0.83

# %%
df_Results_2
# Out:
#                                       Model  max_depth  \
# RandomForest: max_depth=5.00   RandomForest          5
# RandomForest: max_depth=10.00  RandomForest         10
# RandomForest: max_depth=15.00  RandomForest         15
# RandomForest: max_depth=20.00  RandomForest         20
# RandomForest: max_depth=25.00  RandomForest         25
# RandomForest: max_depth=30.00  RandomForest         30
# RandomForest: max_depth=35.00  RandomForest         35
# RandomForest: max_depth=40.00  RandomForest         40
#
#                                            Feature Variables  \
# RandomForest: max_depth=5.00   [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=10.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=15.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=20.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=25.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=30.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=35.00  [Mean_price_paid, Year, X, Y]
# RandomForest: max_depth=40.00  [Mean_price_paid, Year, X, Y]
#
#                                Explained Variance Score         MAE  \
# RandomForest: max_depth=5.00                   0.532859  437.663409
# RandomForest: max_depth=10.00                  0.760883  298.248660
# RandomForest: max_depth=15.00                  0.819619  246.064206
# RandomForest: max_depth=20.00                  0.825601  239.782557
# RandomForest: max_depth=25.00                  0.826562  238.635812
# RandomForest: max_depth=30.00                  0.827012  238.661924
# RandomForest: max_depth=35.00                  0.826846  238.715321
# RandomForest: max_depth=40.00                  0.826846  238.715321
#
#                                          MSE  R2_score
# RandomForest: max_depth=5.00   353052.893734  0.531829
# RandomForest: max_depth=10.00  180637.841597  0.760462
# RandomForest: max_depth=15.00  136305.983429  0.819249
# RandomForest: max_depth=20.00  131779.865139  0.825251
# RandomForest: max_depth=25.00  131069.359435  0.826193
# RandomForest: max_depth=30.00  130720.887799  0.826655
# RandomForest: max_depth=35.00  130846.388514  0.826489
# RandomForest: max_depth=40.00  130846.388514  0.826489

# %% [markdown]
# Explained Variance - improvement appears to be levelling off at 20-25 max_depth at 0.826. This is higher than achieved over the linear or kNN algorithms and the earlier Random Forest model run without the location parameters. The model is dealing much better with variance.
#
# MAE - the MAE is significantly improved over the equivalent kNN model runs and linear models and predicts within ~5% of the mean electricity consumption for the data set.
#
# MSE - is also improved.
#
# R2 - also appears to be levelling out at 0.826, demonstrating the model 'fit' is relatively 'good' - albeit improvements would still be looked for.

# %% [markdown]
# CONCLUSION:
#
# Overall the Random Forest algorithm with feature variables of 'mean price paid', 'year', 'X' and 'Y' performs best overall compared to kNN and linear model equivalent runs. A max_depth of 25 appears to provide the optimum achievable fit with these feature variables.
#
# The model is substantially improved compared to earlier algorithm/model choice and runs (differing feature variables and hyperparameters) but further improvements would still be looked for through addition of other possible feature variables and tuning of hyperparameters.

# %%
#Export results to csv

# %%
df_Results_2.to_csv('2_ModelResults/RandomForest_Results_WalesRural_2.csv')

# %% [markdown]
# ## 2.3.4 - Final Run & Results Printing

# %% [markdown]
# Re-run the model with the identified optimum hyperparameters.

# %%
#Define the model
regr = RandomForestRegressor(n_estimators=100, criterion='mse', max_depth=20, random_state=0)

# %%
#Set the training data
x_train = np.asanyarray(train[['Mean_price_paid','Year', 'X', 'Y']])
y_train = np.asanyarray(train[['Mean_domestic_electricity_consumption_kWh_per_meter']])

# %%
#Train the model on the set training data
regr.fit(x_train, y_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
#Predict results using the trained model and the previously defined test data
y_hat = regr.predict(test[['Mean_price_paid','Year', 'X', 'Y']])

# %%
x_test = np.asanyarray(test[['Mean_price_paid','Year', 'X', 'Y']])
y_test = np.asanyarray(test[['Mean_domestic_electricity_consumption_kWh_per_meter']])

# %%
#Check the shape of the data
y_test = np.squeeze(y_test)
y_test.shape
# Out:
# (814,)

# %%
#Run evaluation metrics to check the model performance & print results to notebook
print("RandomForest: max_depth=20" , ['Mean_price_paid','Year', 'X', 'Y'], ['Rural Wales'])
print("Explained Variance Score: %.2f" % explained_variance_score(y_test, y_hat))
print("MAE: %.2f" % mean_absolute_error(y_test, y_hat))
print("MSE: %.2f" % mean_squared_error(y_test, y_hat))
print("R2-score: %.2f" % r2_score(y_test, y_hat))
print(" ")
# Out:
# RandomForest: max_depth=20 ['Mean_price_paid', 'Year', 'X', 'Y'] ['Rural Wales']
# Explained Variance Score: 0.83
# MAE: 239.78
# MSE: 131779.87
# R2-score: 0.83

# %%
#Set up dataframe of evaluation metrics

df_Metrics = pd.DataFrame({'Explained Variance Score': [explained_variance_score(y_test, y_hat)]},
                  index=["RandomForest: max_depth=20, 'Mean_price_paid','Year', 'X', 'Y', 'Rural Wales'"])
df_Metrics.insert(1,'MAE', mean_absolute_error(y_test, y_hat))
df_Metrics.insert(2,'MSE', mean_squared_error(y_test, y_hat))
df_Metrics.insert(3,'R2_score', r2_score(y_test, y_hat))
df_Metrics.insert(0, 'Model', 'RandomForest')
df_Metrics.insert(1, 'max_depth', '20')
df_Metrics.insert(2, 'Model_Region', 'Rural Wales')
df_Metrics.insert(3, 'Feature Variables', "'Mean_price_paid','Year', 'X', 'Y'")

# %%
df_Metrics
# Out:
#                                                            Model max_depth  \
# RandomForest: max_depth=20, 'Mean_price_paid','...  RandomForest        20
#
#                                                    Model_Region  \
# RandomForest: max_depth=20, 'Mean_price_paid','...  Rural Wales
#
#                                                                      Feature Variables  \
# RandomForest: max_depth=20, 'Mean_price_paid','...  'Mean_price_paid','Year', 'X', 'Y'
#
#                                                     Explained Variance Score  \
# RandomForest: max_depth=20, 'Mean_price_paid','...                  0.825601
#
#                                                            MAE            MSE  \
# RandomForest: max_depth=20, 'Mean_price_paid','...  239.782557  131779.865139
#
#                                                     R2_score
# RandomForest: max_depth=20, 'Mean_price_paid','...  0.825251

# %% [markdown]
# Print predicted electricity results to df and .csv.

# %%
#Set up temporary results df
df = pd.DataFrame({'Predicted_Electricity_Consumption_kWH': y_hat})

# %%
df_ResultsValues = df_test

# %%
df_ResultsValues.insert(12,'Predicted_Electricity_Consumption_kWH', y_hat)

# %%
df_ResultsValues
# Out:
#         Unnamed: 0           X           Y  LSOA code  Unnamed: 0.1  \
# 298930       33427  271303.328  214298.937  W01000718      400954.0
# 293185       33725  248259.273  360024.172  W01000054      394571.0
# 297480       33763  197539.044  207990.376  W01000554      399343.0
# 293850       33139  277455.079  377006.979  W01000131      395310.0
# 293858       33139  277455.079  377006.979  W01000131      395318.0
# 294179       33722  278102.617  381991.107  W01000169      395675.0
# 293623       34422  247078.291  353161.880  W01000104      395057.0
# 294211       33556  281390.658  381196.005  W01000173      395711.0
# 298589       33022  262387.195  214463.187  W01000680      400575.0
# 293907       33133  280473.463  369272.564  W01000137      395373.0
# 298241       33492  241888.931  220802.158  W01000638      400188.0
# 296851       34299  322344.792  296769.862  W01000476      398644.0
# 297067       32955  299329.269  231466.040  W01000503      398884.0
# 298188       33489  244801.301  200738.782  W01000633      400130.0
# 297803       34286  189608.105  205679.265  W01000590      399702.0
# 298039       34319  213336.547  205038.929  W01000616      399964.0
# 298351       33818  252776.135  201214.016  W01000651      400311.0
# 294165       33721  277737.706  381459.653  W01000168      395660.0
# 297490       33764  191727.904  219168.141  W01000555      399354.0
# 309593       32966  251430.589  198927.456  W01001924      412802.0
# 298018       34323  183385.853  207342.556  W01000614      399941.0
# 293658       34432  237467.793  335207.290  W01000108      395096.0
# 297324       34092  260231.986  251880.249  W01000537      399170.0
# 298444       34531  247971.722  208282.306  W01000662      400414.0
# 309700       34291  259884.515  281891.702  W01001936      412921.0
# 293722       33333  260470.643  367730.837  W01000115      395167.0
# 296497       33963  313164.614  237739.516  W01000430      398251.0
# 298629       33012  244535.747  235772.607  W01000685      400620.0
# 298192       33489  244801.301  200738.782  W01000633      400134.0
# 298021       34323  183385.853  207342.556  W01000614      399944.0
# ...            ...         ...         ...        ...           ...
# 294336       34419  278410.745  381152.576  W01000187      395850.0
# 297380       33955  270042.596  279528.913  W01000543      399232.0
# 296516       33961  303657.758  251022.175  W01000432      398272.0
# 297354       33956  251453.388  266962.306  W01000540      399203.0
# 293349       33349  258210.589  331780.949  W01000074      394753.0
# 297988       34726  211807.756  200462.023  W01000610      399907.0
# 296782       32973  295502.690  284061.574  W01000466      398567.0
# 293396       33356  258525.176  327336.478  W01000079      394805.0
# 297303       34093  259143.334  278007.979  W01000534      399146.0
# 298718       34326  242287.024  219240.288  W01000694      400718.0
# 296826       34304  275011.653  300938.603  W01000473      398616.0
# 294341       34419  278410.745  381152.576  W01000187      395855.0
# 297433       33959  264767.007  284180.024  W01000549      399291.0
# 297329       34092  260231.986  251880.249  W01000537      399175.0
# 293315       33353  234375.798  336298.227  W01000070      394715.0
# 294118       33719  296207.709  366252.272  W01000162      395607.0
# 293885       33134  280159.816  361502.885  W01000134      395348.0
# 298462       34529  256755.550  213791.315  W01000664      400434.0
# 298015       34329  215978.916  245786.749  W01000613      399937.0
# 297811       34284  189291.193  206284.214  W01000591      399711.0
# 293857       33139  277455.079  377006.979  W01000131      395317.0
# 298476       34527  257836.587  203619.158  W01000666      400450.0
# 298921       33414  249786.842  211626.651  W01000717      400944.0
# 293379       33348  258623.017  372543.186  W01000077      394786.0
# 297843       34278  190401.326  206344.470  W01000594      399746.0
# 309687       34293  258802.006  282144.644  W01001934      412906.0
# 298341       33817  264749.368  240655.322  W01000650      400300.0
# 298131       33650  262792.118  212409.818  W01000626      400066.0
# 297602       34474  194175.234  237982.979  W01000567      399478.0
# 294215       33556  281390.658  381196.005  W01000173      395715.0
#
#        Local authority name Local authority code            MSOA name  \
# 298930      Carmarthenshire            W06000010  Carmarthenshire 010
# 293185              Gwynedd            W06000002          Gwynedd 007
# 297480        Pembrokeshire            W06000009    Pembrokeshire 009
# 293850                Conwy            W06000003            Conwy 012
# 293858                Conwy            W06000003            Conwy 012
# 294179                Conwy            W06000003            Conwy 001
# 293623              Gwynedd            W06000002          Gwynedd 008
# 294211                Conwy            W06000003            Conwy 003
# 298589      Carmarthenshire            W06000010  Carmarthenshire 011
# 293907                Conwy            W06000003            Conwy 015
# 298241      Carmarthenshire            W06000010  Carmarthenshire 007
# 296851                Powys            W06000023            Powys 005
# 297067                Powys            W06000023            Powys 020
# 298188      Carmarthenshire            W06000010  Carmarthenshire 021
# 297803        Pembrokeshire            W06000009    Pembrokeshire 012
# 298039        Pembrokeshire            W06000009    Pembrokeshire 011
# 298351      Carmarthenshire            W06000010  Carmarthenshire 020
# 294165                Conwy            W06000003            Conwy 002
# 297490        Pembrokeshire            W06000009    Pembrokeshire 008
# 309593      Carmarthenshire            W06000010  Carmarthenshire 026
# 298018        Pembrokeshire            W06000009    Pembrokeshire 008
# 293658              Gwynedd            W06000002          Gwynedd 012
# 297324           Ceredigion            W06000008       Ceredigion 008
# 298444      Carmarthenshire            W06000010  Carmarthenshire 016
# 309700           Ceredigion            W06000008       Ceredigion 003
# 293722              Gwynedd            W06000002          Gwynedd 003
# 296497                Powys            W06000023            Powys 015
# 298629      Carmarthenshire            W06000010  Carmarthenshire 001
# 298192      Carmarthenshire            W06000010  Carmarthenshire 021
# 298021        Pembrokeshire            W06000009    Pembrokeshire 008
# ...                     ...                  ...                  ...
# 294336                Conwy            W06000003            Conwy 002
# 297380           Ceredigion            W06000008       Ceredigion 011
# 296516                Powys            W06000023            Powys 014
# 297354           Ceredigion            W06000008       Ceredigion 005
# 293349              Gwynedd            W06000002          Gwynedd 013
# 297988        Pembrokeshire            W06000009    Pembrokeshire 016
# 296782                Powys            W06000023            Powys 010
# 293396              Gwynedd            W06000002          Gwynedd 013
# 297303           Ceredigion            W06000008       Ceredigion 011
# 298718      Carmarthenshire            W06000010  Carmarthenshire 008
# 296826                Powys            W06000023            Powys 004
# 294341                Conwy            W06000003            Conwy 002
# 297433           Ceredigion            W06000008       Ceredigion 001
# 297329           Ceredigion            W06000008       Ceredigion 008
# 293315              Gwynedd            W06000002          Gwynedd 012
# 294118                Conwy            W06000003            Conwy 014
# 293885                Conwy            W06000003            Conwy 015
# 298462      Carmarthenshire            W06000010  Carmarthenshire 016
# 298015        Pembrokeshire            W06000009    Pembrokeshire 001
# 297811        Pembrokeshire            W06000009    Pembrokeshire 012
# 293857                Conwy            W06000003            Conwy 012
# 298476      Carmarthenshire            W06000010  Carmarthenshire 017
# 298921      Carmarthenshire            W06000010  Carmarthenshire 016
# 293379              Gwynedd            W06000002          Gwynedd 001
# 297843        Pembrokeshire            W06000009    Pembrokeshire 012
# 309687           Ceredigion            W06000008       Ceredigion 002
# 298341      Carmarthenshire            W06000010  Carmarthenshire 002
# 298131      Carmarthenshire            W06000010  Carmarthenshire 013
# 297602        Pembrokeshire            W06000009    Pembrokeshire 002
# 294215                Conwy            W06000003            Conwy 003
#
#         MSOA code             LSOA name  \
# 298930  W02000151  Carmarthenshire 010D
# 293185  W02000016          Gwynedd 007A
# 297480  W02000134    Pembrokeshire 009A
# 293850  W02000038            Conwy 012D
# 293858  W02000038            Conwy 012D
# 294179  W02000027            Conwy 001D
# 293623  W02000017          Gwynedd 008C
# 294211  W02000029            Conwy 003B
# 298589  W02000152  Carmarthenshire 011A
# 293907  W02000041            Conwy 015C
# 298241  W02000148  Carmarthenshire 007B
# 296851  W02000101            Powys 005C
# 297067  W02000414            Powys 020C
# 298188  W02000162  Carmarthenshire 021B
# 297803  W02000137    Pembrokeshire 012B
# 298039  W02000136    Pembrokeshire 011F
# 298351  W02000161  Carmarthenshire 020A
# 294165  W02000028            Conwy 002B
# 297490  W02000133    Pembrokeshire 008A
# 309593  W02000167  Carmarthenshire 026H
# 298018  W02000133    Pembrokeshire 008D
# 293658  W02000021          Gwynedd 012D
# 297324  W02000123       Ceredigion 008D
# 298444  W02000157  Carmarthenshire 016A
# 309700  W02000118       Ceredigion 003F
# 293722  W02000012          Gwynedd 003E
# 296497  W02000111            Powys 015A
# 298629  W02000142  Carmarthenshire 001A
# 298192  W02000162  Carmarthenshire 021B
# 298021  W02000133    Pembrokeshire 008D
# ...           ...                   ...
# 294336  W02000028            Conwy 002C
# 297380  W02000421       Ceredigion 011C
# 296516  W02000110            Powys 014B
# 297354  W02000120       Ceredigion 005E
# 293349  W02000022          Gwynedd 013B
# 297988  W02000141    Pembrokeshire 016A
# 296782  W02000106            Powys 010C
# 293396  W02000022          Gwynedd 013C
# 297303  W02000421       Ceredigion 011B
# 298718  W02000149  Carmarthenshire 008D
# 296826  W02000100            Powys 004C
# 294341  W02000028            Conwy 002C
# 297433  W02000116       Ceredigion 001E
# 297329  W02000123       Ceredigion 008D
# 293315  W02000021          Gwynedd 012A
# 294118  W02000040            Conwy 014C
# 293885  W02000041            Conwy 015B
# 298462  W02000157  Carmarthenshire 016C
# 298015  W02000126    Pembrokeshire 001E
# 297811  W02000137    Pembrokeshire 012C
# 293857  W02000038            Conwy 012D
# 298476  W02000158  Carmarthenshire 017B
# 298921  W02000157  Carmarthenshire 016E
# 293379  W02000010          Gwynedd 001C
# 297843  W02000137    Pembrokeshire 012E
# 309687  W02000117       Ceredigion 002F
# 298341  W02000143  Carmarthenshire 002B
# 298131  W02000154  Carmarthenshire 013B
# 297602  W02000127    Pembrokeshire 002D
# 294215  W02000029            Conwy 003B
#
#         Total_number_of_domestic_electricity_meters  \
# 298930                                        676.0
# 293185                                        472.0
# 297480                                        790.0
# 293850                                        640.0
# 293858                                        678.0
# 294179                                       1002.0
# 293623                                        874.0
# 294211                                        701.0
# 298589                                        900.0
# 293907                                        655.0
# 298241                                        520.0
# 296851                                        637.0
# 297067                                        443.0
# 298188                                        781.0
# 297803                                        621.0
# 298039                                        854.0
# 298351                                        722.0
# 294165                                        813.0
# 297490                                        611.0
# 309593                                        665.0
# 298018                                        774.0
# 293658                                       1187.0
# 297324                                        638.0
# 298444                                        994.0
# 309700                                        438.0
# 293722                                        930.0
# 296497                                        589.0
# 298629                                        677.0
# 298192                                        782.0
# 298021                                        781.0
# ...                                             ...
# 294336                                        650.0
# 297380                                        967.0
# 296516                                        570.0
# 297354                                        598.0
# 293349                                       1244.0
# 297988                                        827.0
# 296782                                        631.0
# 293396                                        678.0
# 297303                                        680.0
# 298718                                        632.0
# 296826                                       1110.0
# 294341                                        658.0
# 297433                                        745.0
# 297329                                        640.0
# 293315                                        612.0
# 294118                                        717.0
# 293885                                       1018.0
# 298462                                        897.0
# 298015                                       1209.0
# 297811                                        498.0
# 293857                                        674.0
# 298476                                        663.0
# 298921                                        710.0
# 293379                                        615.0
# 297843                                       1074.0
# 309687                                       1114.0
# 298341                                        651.0
# 298131                                        823.0
# 297602                                       1006.0
# 294215                                        709.0
#
#         Total_domestic_electricity_consumption_kWh  \
# 298930                                 2354054.000
# 293185                                 2102392.500
# 297480                                 3968741.300
# 293850                                 2406385.900
# 293858                                 2045810.700
# 294179                                 3344453.738
# 293623                                 3057817.000
# 294211                                 2851320.100
# 298589                                 3888123.600
# 293907                                 3758261.000
# 298241                                 1684259.100
# 296851                                 3592140.000
# 297067                                 2537100.000
# 298188                                 2164890.500
# 297803                                 2037000.000
# 298039                                 3036214.000
# 298351                                 2337697.500
# 294165                                 3022964.400
# 297490                                 2802631.000
# 309593                                 1866385.300
# 298018                                 3466874.800
# 293658                                 4009260.200
# 297324                                 3466376.900
# 298444                                 3608476.000
# 309700                                 2413025.600
# 293722                                 4063469.350
# 296497                                 2911139.700
# 298629                                 3136245.000
# 298192                                 2127678.000
# 298021                                 3510148.000
# ...                                            ...
# 294336                                 2291098.000
# 297380                                 6150426.200
# 296516                                 1968914.400
# 297354                                 3267755.300
# 293349                                 6637989.900
# 297988                                 3316950.200
# 296782                                 2250450.300
# 293396                                 3560955.600
# 297303                                 3466092.900
# 298718                                 2361093.167
# 296826                                 4366071.233
# 294341                                 2255983.838
# 297433                                 6122581.800
# 297329                                 3220404.900
# 293315                                 3101701.050
# 294118                                 3793740.000
# 293885                                 3119737.652
# 298462                                 3977811.000
# 298015                                 5299294.200
# 297811                                 2027240.200
# 293857                                 2201526.117
# 298476                                 2163545.800
# 298921                                 2268527.000
# 293379                                 1774378.200
# 297843                                 3260233.900
# 309687                                 4467213.700
# 298341                                 3247941.500
# 298131                                 2366340.100
# 297602                                 3175241.800
# 294215                                 2829079.000
#
#         Predicted_Electricity_Consumption_kWH  \
# 298930                            3488.204540
# 293185                            4300.669498
# 297480                            4986.493130
# 293850                            3896.055558
# 293858                            3161.989502
# 294179                            3460.524738
# 293623                            3734.697349
# 294211                            3966.679430
# 298589                            3993.221514
# 293907                            5731.498693
# 298241                            3293.183380
# 296851                            5267.887535
# 297067                            5605.527967
# 298188                            3165.511963
# 297803                            3492.956590
# 298039                            3463.617602
# 298351                            3299.478399
# 294165                            3855.162508
# 297490                            4811.686385
# 309593                            2762.942547
# 298018                            4284.278050
# 293658                            4473.599844
# 297324                            5426.620090
# 298444                            4182.728337
# 309700                            4927.506582
# 293722                            4258.040898
# 296497                            4982.273014
# 298629                            4419.745488
# 298192                            3036.109970
# 298021                            4506.551451
# ...                                       ...
# 294336                            3723.323736
# 297380                            4393.043172
# 296516                            3547.781833
# 297354                            4836.814430
# 293349                            4972.487710
# 297988                            3969.954915
# 296782                            3325.404984
# 293396                            5115.120652
# 297303                            4865.439197
# 298718                            4131.611401
# 296826                            3727.424537
# 294341                            3379.781856
# 297433                            6372.200223
# 297329                            5127.314608
# 293315                            4678.917356
# 294118                            5294.514936
# 293885                            3868.473224
# 298462                            4271.762378
# 298015                            4214.029005
# 297811                            3742.344299
# 293857                            3188.067952
# 298476                            3307.040933
# 298921                            3881.551321
# 293379                            3176.668988
# 297843                            3105.967390
# 309687                            3958.908419
# 298341                            5027.255794
# 298131                            3392.570925
# 297602                            3756.305167
# 294215                            3573.050086
#
#         Mean_domestic_electricity_consumption_kWh_per_meter  \
# 298930                                        3482.000000
# 293185                                        4454.221398
# 297480                                        5023.723165
# 293850                                        3759.977969
# 293858                                        3017.419912
# 294179                                        3337.778181
# 293623                                        3498.646453
# 294211                                        4067.503709
# 298589                                        4320.137333
# 293907                                        5737.803053
# 298241                                        3238.959808
# 296851                                        5639.000000
# 297067                                        5727.000000
# 298188                                        2771.946863
# 297803                                        3280.193237
# 298039                                        3555.000000
# 298351                                        3237.808172
# 294165                                        3718.283395
# 297490                                        4587.000000
# 309593                                        2806.594436
# 298018                                        4479.166408
# 293658                                        3377.641281
# 297324                                        5433.192633
# 298444                                        3630.000000
# 309700                                        5509.190868
# 293722                                        4369.321882
# 296497                                        4942.512224
# 298629                                        4632.562777
# 298192                                        2721.000000
# 298021                                        4494.000000
# ...                                                   ...
# 294336                                        3524.766154
# 297380                                        6360.316649
# 296516                                        3454.235790
# 297354                                        5464.473746
# 293349                                        5336.004743
# 297988                                        4010.822491
# 296782                                        3566.482250
# 293396                                        5252.146903
# 297303                                        5097.195441
# 298718                                        3735.906909
# 296826                                        3933.397508
# 294341                                        3428.546866
# 297433                                        8218.230604
# 297329                                        5031.882656
# 293315                                        5068.138971
# 294118                                        5291.129707
# 293885                                        3064.575297
# 298462                                        4435.000000
# 298015                                        4383.204467
# 297811                                        4070.763454
# 293857                                        3266.359224
# 298476                                        3263.266667
# 298921                                        3195.000000
# 293379                                        2885.167805
# 297843                                        3035.599535
# 309687                                        4010.066158
# 298341                                        4989.157450
# 298131                                        2875.261361
# 297602                                        3156.303976
# 294215                                        3990.238364
#
#         Median_domestic_electricity_consumption_kWh_per_meter    Year  \
# 298930                                            3080.00      2014.0
# 293185                                            3719.45      2011.0
# 297480                                            4311.25      2013.0
# 293850                                            3273.90      2010.0
# 293858                                            2696.20      2018.0
# 294179                                            2301.10      2015.0
# 293623                                            2807.25      2017.0
# 294211                                            3194.00      2011.0
# 298589                                            3432.05      2015.0
# 293907                                            4361.80      2013.0
# 298241                                            2825.30      2018.0
# 296851                                            4115.00      2014.0
# 297067                                            4286.00      2014.0
# 298188                                            2195.90      2010.0
# 297803                                            2926.10      2012.0
# 298039                                            2424.00      2014.0
# 298351                                            2804.55      2011.0
# 294165                                            3185.30      2010.0
# 297490                                            3744.00      2014.0
# 309593                                            2455.90      2012.0
# 298018                                            3608.20      2011.0
# 293658                                            2650.80      2016.0
# 297324                                            4364.85      2010.0
# 298444                                            2943.00      2014.0
# 309700                                            3919.20      2011.0
# 293722                                            3563.55      2017.0
# 296497                                            3595.90      2011.0
# 298629                                            3612.30      2010.0
# 298192                                            2357.00      2014.0
# 298021                                            3415.00      2014.0
# ...                                                   ...         ...
# 294336                                            3200.70      2010.0
# 297380                                            4501.00      2012.0
# 296516                                            2948.70      2012.0
# 297354                                            4067.20      2013.0
# 293349                                            4211.70      2013.0
# 297988                                            2914.90      2017.0
# 296782                                            2721.80      2017.0
# 293396                                            3806.80      2015.0
# 297303                                            3944.65      2016.0
# 298718                                            2889.10      2018.0
# 296826                                            3054.05      2016.0
# 294341                                            3071.95      2015.0
# 297433                                            6779.30      2011.0
# 297329                                            3947.75      2015.0
# 293315                                            4201.60      2015.0
# 294118                                            3981.90      2017.0
# 293885                                            2501.45      2018.0
# 298462                                            3565.00      2014.0
# 298015                                            3048.00      2017.0
# 297811                                            3519.20      2011.0
# 293857                                            2776.00      2017.0
# 298476                                            2888.60      2010.0
# 298921                                            2768.00      2014.0
# 293379                                            2366.00      2016.0
# 297843                                            2587.00      2016.0
# 309687                                            2960.40      2016.0
# 298341                                            4116.20      2010.0
# 298131                                            2436.60      2016.0
# 297602                                            2671.70      2018.0
# 294215                                            3118.20      2015.0
#
#         Ratio_Consumption_per_Meter  Mean_price_paid
# 298930                  3482.328402     82854.062500
# 293185                  4454.221398    122695.833335
# 297480                  5023.723165    213883.170833
# 293850                  3759.977969    146431.109852
# 293858                  3017.419912    213943.442573
# 294179                  3337.778182    155560.029760
# 293623                  3498.646453    110875.568183
# 294211                  4067.503709    135308.026620
# 298589                  4320.137333    154332.900190
# 293907                  5737.803053    199751.189062
# 298241                  3238.959808    114833.928571
# 296851                  5639.152276    231517.530633
# 297067                  5727.088036    245364.468343
# 298188                  2771.946863    120352.878787
# 297803                  3280.193237    140699.404763
# 298039                  3555.285714    257685.469907
# 298351                  3237.808172     96496.392496
# 294165                  3718.283395    126633.143940
# 297490                  4586.957447    249726.736110
# 309593                  2806.594436     52066.808036
# 298018                  4479.166408    157255.833335
# 293658                  3377.641281    147851.662580
# 297324                  5433.192633    174065.634675
# 298444                  3630.257545    163799.973643
# 309700                  5509.190868    218447.556090
# 293722                  4369.321882    195996.826702
# 296497                  4942.512224    195620.753205
# 298629                  4632.562777    144735.416667
# 298192                  2720.815857     93570.731356
# 298021                  4494.427657    219611.721615
# ...                             ...              ...
# 294336                  3524.766154     26822.500000
# 297380                  6360.316649    154216.602272
# 296516                  3454.235789    185354.891100
# 297354                  5464.473746    140520.133928
# 293349                  5336.004743    151597.818853
# 297988                  4010.822491    280248.104535
# 296782                  3566.482250    137547.524555
# 293396                  5252.146903    201778.420140
# 297303                  5097.195441    239058.281250
# 298718                  3735.906910    211626.131107
# 296826                  3933.397507    127618.972685
# 294341                  3428.546866     95947.172619
# 297433                  8218.230604    164173.103985
# 297329                  5031.882656    183850.568182
# 293315                  5068.138971    201523.622815
# 294118                  5291.129707    213512.964465
# 293885                  3064.575297    155678.817830
# 298462                  4434.571906    138157.487037
# 298015                  4383.204467    202971.565338
# 297811                  4070.763454    120938.492062
# 293857                  3266.359224    229730.355625
# 298476                  3263.266667    115243.327245
# 298921                  3195.108451    124906.413920
# 293379                  2885.167805    123128.223475
# 297843                  3035.599534     94048.328951
# 309687                  4010.066158    197566.670140
# 298341                  4989.157450    162074.053032
# 298131                  2875.261361    124629.651590
# 297602                  3156.303976    147375.959742
# 294215                  3990.238364    150362.185897
#
# [814 rows x 18 columns]

# %%
plt.rcParams['figure.figsize'] = [16, 10]

# %%
plt.style.use('seaborn-darkgrid')

# %%
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15) 
matplotlib.rc('axes', labelsize=20) 
matplotlib.rc('axes', titlesize=20)

# %%
plt.scatter(df_ResultsValues.Mean_price_paid, df_ResultsValues.Mean_domestic_electricity_consumption_kWh_per_meter, color='blue')
plt.scatter(df_ResultsValues.Mean_price_paid, df_ResultsValues.Predicted_Electricity_Consumption_kWH, color='green')
plt.xlabel("Mean Price Paid (£)")
plt.ylabel("Mean Consumption by LSOA (mean per meter) (kWh)")
plt.legend(fontsize=15)
plt.title("Mean price paid against Predicted & Mean Electricity Consumption for LSOAs in Rural Wales from 2010 to 2018")
plt.show()

# %%
plt.scatter(df_ResultsValues.Y, df_ResultsValues.Mean_domestic_electricity_consumption_kWh_per_meter, color='blue')
plt.scatter(df_ResultsValues.Y, df_ResultsValues.Predicted_Electricity_Consumption_kWH, color='green')
plt.xlabel("Y Coordinate")
plt.ylabel("Mean_domestic_electricity_consumption_kWh_per_meter")
plt.legend()
plt.title("Y Coordinate against Predicted & Mean Electricity Consumption for LSOAs in Rural Wales from 2010 to 2018")
plt.show()

# %%
plt.scatter(df_ResultsValues.Year, df_ResultsValues.Mean_domestic_electricity_consumption_kWh_per_meter, color='blue')
plt.scatter(df_ResultsValues.Year, df_ResultsValues.Predicted_Electricity_Consumption_kWH, color='green')
plt.xlabel("Year")
plt.ylabel("Mean_domestic_electricity_consumption_kWh_per_meter")
plt.legend()
plt.title("Year against Predicted & Mean Electricity Consumption for LSOAs in Rural Wales from 2010 to 2018")
plt.show()

# %% [markdown]
# Check on the most influencing feature variables.
#
# Location (Y coordinate) and mean price paid in this instance influence equally. Year has little influence.

# %%
regr.feature_importances_
# Out:
# array([0.36139006, 0.0719132 , 0.19069339, 0.37600335])

# %%
#Export results to csv

# %%
df_ResultsValues.to_csv('2_ModelResults/PredictedValues/RandomForest_WalesRural.csv')

# %%
df_Metrics.to_csv('2_ModelResults/PredictedValues/RandomForest_WalesRural_ME.csv')

# %%
#END
